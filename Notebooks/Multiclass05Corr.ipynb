# %%
# All imports
from Imports import *
from Preprocessing import *
from Helper import *
# %matplotlib inline
warnings.filterwarnings('ignore')

# %%
# Load dataset and device
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# Data paths
TRAIN_FILE = '../Data/2025-Quantathon-Tornado-Q-training_data-640-examples.xlsx'
TEST_FILE = '../Data/2025-Quantum-Tornado-Q-test_data-200-examples.xlsx'
VALIDATION_FILE = '../Data/2025-Quantum-Tornado-validation_data-160-examples.xlsx'

# Load training data
df_train = pd.read_excel(TRAIN_FILE)
# Load test data
df_test = pd.read_excel(TEST_FILE)
# Load validation data
df_val = pd.read_excel(VALIDATION_FILE)

if True:
    EXTRA_TRAIN = "../Data/retired_data/32_featuresXY_train_05corr.csv"
    EXTRA_TEST = "../Data/retired_data/32_featuresXY_test_05corr.csv"
    EXTRA_VALID = "../Data/retired_data/32_featuresXY_test_05corr.csv"
    
    # Extra features
    extra_train_df = pd.read_csv(EXTRA_TRAIN)
    extra_test_df = pd.read_csv(EXTRA_TEST)
    extra_valid_df = pd.read_csv(EXTRA_VALID)
    
    # Drop first column by index
    extra_train_df = extra_train_df.drop(extra_train_df.columns[0], axis=1)
    extra_test_df = extra_test_df.drop(extra_test_df.columns[0], axis=1)
    extra_valid_df = extra_valid_df.drop(extra_valid_df.columns[0], axis=1)
    
    # Concatenate extra features (axis=1 for columns)
    df_train = pd.concat([df_train, extra_train_df], axis=1)
    df_test  = pd.concat([df_test, extra_test_df], axis=1)
    df_val  = pd.concat([df_val, extra_valid_df], axis=1)


print(f"✓ Training data loaded: {df_train.shape[0]} rows, {df_train.shape[1]} columns")
print(f"✓ Test data loaded: {df_test.shape[0]} rows, {df_test.shape[1]} columns")
# Out:
# ✓ Training data loaded: 640 rows, 42 columns
# ✓ Test data loaded: 200 rows, 42 columns

# %%
# Binary DN without Quantum Layer
class BinaryDNN(nn.Module):
    def __init__(self):
        super().__init__()

        # Encodes features from dataset
        self.feature_encoder = nn.Sequential(
            nn.Linear(40, 64),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.2),
            nn.Linear(64, 128),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.2),
            nn.Linear(128, 1024),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.3),
        )

        # Classifies based on encoded features
        self.classifier = nn.Sequential(
            nn.Linear(1024, 128),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.2),
            nn.Linear(64, 4)
        )

    def forward(self, features):
        feats_encoded = self.feature_encoder(features)
        class_target = self.classifier(feats_encoded)

        return class_target  # Shape: (batch_size, 4)

# %%
# Define variable and dataset
batch_size = 64
lr = 1e-2

X_train, y_train, X_test, y_test, X_val, y_val = Preprocess(df_train, df_test, df_val, balance = 'smote', classes = 'binary')

print(y_test[:])
print(y_train[:])

train_data = ClassificationDataset(X_train, y_train)
validation_data = ClassificationDataset(X_val, y_val)
test_data = ClassificationDataset(X_test, y_test)


train_loader = DataLoader(train_data, batch_size=64, shuffle=True, drop_last=True)
val_loader = DataLoader(validation_data, batch_size=64, shuffle=False, drop_last=True)
test_loader = DataLoader(test_data, batch_size=64, shuffle=False, drop_last=True)

X_batch, y_batch = next(iter(train_loader))

print("Batch X dtype:", X_batch.dtype)
print("Batch y dtype:", y_batch.dtype)

print("Number of training samples:", len(train_data))
print("Number of validation samples:", len(validation_data))
print("Number of test samples:", len(test_data))
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      1
#       ..
# 195    0
# 196    0
# 197    1
# 198    0
# 199    0
# Name: ef_binary, Length: 200, dtype: int64
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1137    1
# 1138    1
# 1139    1
# 1140    1
# 1141    1
# Name: ef_binary, Length: 1142, dtype: int64
# Batch X dtype: torch.float32
# Batch y dtype: torch.float32
# Number of training samples: 1142
# Number of validation samples: 200
# Number of test samples: 200

# %%
# Initialize model, optimizer, and scheduler
n_epochs = 1000

DNN = BinaryDNN().to(device)
optimizer = optim.Adam(DNN.parameters(), lr=lr, betas=(0.9, 0.999))
scheduler_G = CosineAnnealingLR(optimizer, T_max=n_epochs, eta_min=1e-4)

# Empty array to track losses
losses = []

# %%
# # Plot visual of DNN
# graph =  draw_graph(
#     DNN,
#     input_size=(1, 8),
#     expand_nested=True,
#     depth = 1,
#     graph_name="DNN Architecture",
#     mode = 'train',
#     show_shapes = True,
#     hide_inner_tensors=True,   # Hides intermediate shapes
#     roll=True,                  # More compact layer grouping
#     save_graph=False,           # Set to True if you want to save
#     # node_attr={"color": "lightblue", "style": "filled"},  # Node styling
#     # edge_attr={"color": "gray"},                          # Edge styling
#     graph_dir= "TB",                         # Layout: TB (top-bottom), LR (left-right)
# )

# # Show in notebook
# graph.visual_graph

# %%
## Load a previous model
load = False

if load:
    # load_path = "models/Binary_DNN_" # Path to load model
    
    # Load the checkpoint
    checkpoint = torch.load(load_path)
    
    # Restore model weights
    DNN.load_state_dict(checkpoint["DNN_state_dict"])
    
    # Optionally restore tracking data
    losses = checkpoint["losses"]
        
    print(f"Loaded model from {load_path}")

# %%
cross_entropy = nn.CrossEntropyLoss()
metric = lambda outputs, target: (torch.argmax(outputs, dim=1) == target).float().mean().item()
best_val_metric = 0
best_val_loss = 999

history = {'epoch': [], 'train_loss': [], 'train_metric': [], 'val_loss': [], 'val_metric': []}

for epoch in range(n_epochs):
    DNN.train()
    train_loss, train_metric = 0.0, 0.0

    for features, target in train_loader:
        features, target = features.to(device), target.to(device).long()  # targets shape: (batch_size,)

        optimizer.zero_grad()
        outputs = DNN(features)              # logits: (batch_size, num_classes)
        loss = cross_entropy(outputs, target)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        train_metric += metric(outputs, target)

    train_loss /= len(train_loader)
    train_metric /= len(train_loader)

    # Validation
    DNN.eval()
    val_loss, val_metric = 0.0, 0.0
    with torch.no_grad():
        for X_val, y_val in val_loader:
            X_val, y_val = X_val.to(device), y_val.to(device).long()
            outputs = DNN(X_val)
            val_loss += cross_entropy(outputs, y_val).item()
            val_metric += metric(outputs, y_val)

    val_loss /= len(val_loader)
    val_metric /= len(val_loader)

    history['epoch'].append(epoch)
    history['train_loss'].append(train_loss)
    history['train_metric'].append(train_metric)
    history['val_loss'].append(val_loss)
    history['val_metric'].append(val_metric)

    if epoch % 10 == 9:
        print(f'Epoch [{epoch+1}/{n_epochs}] | Train Loss: {train_loss:.4f} | '
              f'Train Acc: {train_metric:.4f} | Val Loss: {val_loss:.4f} | Val Acc: {val_metric:.4f}')

    # Save best model (accuracy)
    if val_metric > best_val_metric:
        best_val_metric = val_metric
        os.makedirs("models", exist_ok=True)
        save_path = "models/DNN_multiclass_best_accuracy.pt"
        torch.save({"DNN_state_dict": DNN.state_dict(), "history": history}, save_path)
        print(f'Epoch [{epoch+1}] had best val_metric')
        

    # Save best model (val loss)
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        os.makedirs("models", exist_ok=True)
        save_path = "models/DNN_multiclass_best_valLoss.pt"
        torch.save({"DNN_state_dict": DNN.state_dict(), "history": history}, save_path)
        print(f'Epoch [{epoch+1}] had best val loss')
# Out:
# Epoch [1] had best val_metric
# Epoch [1] had best val loss
# Epoch [2] had best val_metric
# Epoch [2] had best val loss
# Epoch [3] had best val loss
# Epoch [4] had best val_metric
# Epoch [4] had best val loss
# Epoch [5] had best val_metric
# Epoch [5] had best val loss
# Epoch [6] had best val loss
# Epoch [7] had best val_metric
# Epoch [7] had best val loss
# Epoch [8] had best val_metric
# Epoch [8] had best val loss
# Epoch [9] had best val loss
# Epoch [10/1000] | Train Loss: 1.1657 | Train Acc: 0.4980 | Val Loss: 1.1380 | Val Acc: 0.5078
# Epoch [11] had best val loss
# Epoch [14] had best val_metric
# Epoch [14] had best val loss
# Epoch [15] had best val loss
# Epoch [16] had best val_metric
# Epoch [16] had best val loss
# Epoch [20/1000] | Train Loss: 0.9013 | Train Acc: 0.6025 | Val Loss: 0.9008 | Val Acc: 0.5703
# Epoch [21] had best val_metric
# Epoch [21] had best val loss
# Epoch [22] had best val loss
# Epoch [28] had best val_metric
# Epoch [30/1000] | Train Loss: 0.8484 | Train Acc: 0.6475 | Val Loss: 1.2461 | Val Acc: 0.6016
# Epoch [32] had best val loss
# Epoch [37] had best val_metric
# Epoch [40/1000] | Train Loss: 0.8216 | Train Acc: 0.6592 | Val Loss: 0.8821 | Val Acc: 0.5898
# Epoch [46] had best val_metric
# Epoch [46] had best val loss
# Epoch [47] had best val_metric
# Epoch [47] had best val loss
# Epoch [50/1000] | Train Loss: 0.6776 | Train Acc: 0.7061 | Val Loss: 0.6945 | Val Acc: 0.7070
# Epoch [51] had best val loss
# Epoch [60/1000] | Train Loss: 0.6869 | Train Acc: 0.7119 | Val Loss: 0.7134 | Val Acc: 0.6992
# Epoch [61] had best val loss
# Epoch [67] had best val_metric
# Epoch [70/1000] | Train Loss: 0.6789 | Train Acc: 0.7070 | Val Loss: 0.8714 | Val Acc: 0.7305
# Epoch [80/1000] | Train Loss: 0.6293 | Train Acc: 0.7295 | Val Loss: 0.8907 | Val Acc: 0.7148
# Epoch [90/1000] | Train Loss: 0.7169 | Train Acc: 0.7295 | Val Loss: 0.6890 | Val Acc: 0.7031
# Epoch [100/1000] | Train Loss: 0.7342 | Train Acc: 0.7090 | Val Loss: 0.8012 | Val Acc: 0.6445
# Epoch [105] had best val_metric
# Epoch [110/1000] | Train Loss: 0.6927 | Train Acc: 0.7354 | Val Loss: 0.7115 | Val Acc: 0.7422
# Epoch [112] had best val_metric
# Epoch [120/1000] | Train Loss: 0.8393 | Train Acc: 0.6787 | Val Loss: 0.7766 | Val Acc: 0.7070
# Epoch [130/1000] | Train Loss: 0.7255 | Train Acc: 0.7197 | Val Loss: 0.7631 | Val Acc: 0.7383
# Epoch [132] had best val_metric
# Epoch [140/1000] | Train Loss: 0.5209 | Train Acc: 0.7959 | Val Loss: 0.9321 | Val Acc: 0.7344
# Epoch [150/1000] | Train Loss: 0.5599 | Train Acc: 0.7939 | Val Loss: 0.7521 | Val Acc: 0.7188
# Epoch [158] had best val_metric
# Epoch [160/1000] | Train Loss: 0.6418 | Train Acc: 0.7471 | Val Loss: 0.8131 | Val Acc: 0.7461
# Epoch [170/1000] | Train Loss: 0.4923 | Train Acc: 0.8027 | Val Loss: 0.6821 | Val Acc: 0.7461
# Epoch [172] had best val_metric
# Epoch [180/1000] | Train Loss: 0.9261 | Train Acc: 0.6826 | Val Loss: 0.8455 | Val Acc: 0.7031
# Epoch [190/1000] | Train Loss: 0.4830 | Train Acc: 0.8105 | Val Loss: 0.7179 | Val Acc: 0.7539
# Epoch [200/1000] | Train Loss: 0.6560 | Train Acc: 0.7480 | Val Loss: 0.7568 | Val Acc: 0.7305
# Epoch [210/1000] | Train Loss: 0.5193 | Train Acc: 0.8027 | Val Loss: 0.9306 | Val Acc: 0.7461
# Epoch [220/1000] | Train Loss: 0.5758 | Train Acc: 0.7881 | Val Loss: 1.0826 | Val Acc: 0.7461
# Epoch [230/1000] | Train Loss: 0.7405 | Train Acc: 0.7402 | Val Loss: 0.9357 | Val Acc: 0.7422
# Epoch [240/1000] | Train Loss: 0.4413 | Train Acc: 0.8271 | Val Loss: 1.1542 | Val Acc: 0.7461
# Epoch [250/1000] | Train Loss: 0.6745 | Train Acc: 0.7949 | Val Loss: 0.9931 | Val Acc: 0.7422
# Epoch [260/1000] | Train Loss: 0.5355 | Train Acc: 0.8135 | Val Loss: 1.0279 | Val Acc: 0.7891
# Epoch [260] had best val_metric
# Epoch [265] had best val_metric
# Epoch [270/1000] | Train Loss: 0.5728 | Train Acc: 0.7842 | Val Loss: 1.1239 | Val Acc: 0.7383
# Epoch [280/1000] | Train Loss: 0.4275 | Train Acc: 0.8330 | Val Loss: 1.4067 | Val Acc: 0.7617
# Epoch [290/1000] | Train Loss: 0.6259 | Train Acc: 0.7852 | Val Loss: 0.9349 | Val Acc: 0.6797
# Epoch [300/1000] | Train Loss: 0.4302 | Train Acc: 0.8359 | Val Loss: 0.9314 | Val Acc: 0.7812
# Epoch [310/1000] | Train Loss: 0.7048 | Train Acc: 0.7656 | Val Loss: 0.9516 | Val Acc: 0.7109
# Epoch [320/1000] | Train Loss: 0.6718 | Train Acc: 0.7959 | Val Loss: 0.7531 | Val Acc: 0.7656
# Epoch [330/1000] | Train Loss: 0.7666 | Train Acc: 0.7734 | Val Loss: 1.2757 | Val Acc: 0.7617
# Epoch [340/1000] | Train Loss: 0.4116 | Train Acc: 0.8418 | Val Loss: 1.2460 | Val Acc: 0.7656
# Epoch [350/1000] | Train Loss: 0.5440 | Train Acc: 0.8115 | Val Loss: 1.1657 | Val Acc: 0.7422
# Epoch [360/1000] | Train Loss: 0.5447 | Train Acc: 0.8311 | Val Loss: 1.0600 | Val Acc: 0.7578
# Epoch [370/1000] | Train Loss: 0.4893 | Train Acc: 0.8154 | Val Loss: 1.7819 | Val Acc: 0.7461
# Epoch [380/1000] | Train Loss: 0.5475 | Train Acc: 0.8359 | Val Loss: 1.1151 | Val Acc: 0.7461
# Epoch [390/1000] | Train Loss: 0.5802 | Train Acc: 0.8213 | Val Loss: 1.1650 | Val Acc: 0.7617
# Epoch [400/1000] | Train Loss: 0.6728 | Train Acc: 0.8008 | Val Loss: 1.4584 | Val Acc: 0.7617
# Epoch [410/1000] | Train Loss: 0.4406 | Train Acc: 0.8438 | Val Loss: 1.3780 | Val Acc: 0.7578
# Epoch [412] had best val_metric
# Epoch [420/1000] | Train Loss: 0.4225 | Train Acc: 0.8721 | Val Loss: 0.6943 | Val Acc: 0.7852
# Epoch [430/1000] | Train Loss: 0.4736 | Train Acc: 0.8564 | Val Loss: 1.4180 | Val Acc: 0.7695
# Epoch [431] had best val_metric
# Epoch [440/1000] | Train Loss: 0.5914 | Train Acc: 0.8115 | Val Loss: 1.3451 | Val Acc: 0.7617
# Epoch [450/1000] | Train Loss: 1.0083 | Train Acc: 0.7598 | Val Loss: 0.8927 | Val Acc: 0.7500
# Epoch [460/1000] | Train Loss: 0.5742 | Train Acc: 0.7881 | Val Loss: 0.8519 | Val Acc: 0.7617
# Epoch [470/1000] | Train Loss: 0.3810 | Train Acc: 0.8643 | Val Loss: 1.3556 | Val Acc: 0.7539
# Epoch [480/1000] | Train Loss: 0.3671 | Train Acc: 0.8848 | Val Loss: 1.2364 | Val Acc: 0.7617
# Epoch [490/1000] | Train Loss: 0.2854 | Train Acc: 0.8945 | Val Loss: 1.3641 | Val Acc: 0.7344
# Epoch [500/1000] | Train Loss: 0.4679 | Train Acc: 0.8428 | Val Loss: 1.1242 | Val Acc: 0.7617
# Epoch [510/1000] | Train Loss: 0.6943 | Train Acc: 0.7998 | Val Loss: 2.4418 | Val Acc: 0.7539
# Epoch [520/1000] | Train Loss: 1.3321 | Train Acc: 0.7070 | Val Loss: 1.9865 | Val Acc: 0.7188
# Epoch [530/1000] | Train Loss: 0.6374 | Train Acc: 0.8047 | Val Loss: 0.9260 | Val Acc: 0.7461
# Epoch [540/1000] | Train Loss: 0.6272 | Train Acc: 0.7920 | Val Loss: 1.3247 | Val Acc: 0.7109
# Epoch [550/1000] | Train Loss: 0.2907 | Train Acc: 0.8975 | Val Loss: 1.4810 | Val Acc: 0.7852
# Epoch [560/1000] | Train Loss: 0.5243 | Train Acc: 0.8281 | Val Loss: 1.9144 | Val Acc: 0.7734
# Epoch [570/1000] | Train Loss: 0.3608 | Train Acc: 0.8828 | Val Loss: 1.3765 | Val Acc: 0.7539
# Epoch [580/1000] | Train Loss: 0.3630 | Train Acc: 0.8779 | Val Loss: 1.2400 | Val Acc: 0.7773
# Epoch [590/1000] | Train Loss: 2.8533 | Train Acc: 0.4512 | Val Loss: 1.6898 | Val Acc: 0.5664
# Epoch [600/1000] | Train Loss: 0.5006 | Train Acc: 0.8389 | Val Loss: 1.6876 | Val Acc: 0.7656
# Epoch [610/1000] | Train Loss: 0.4479 | Train Acc: 0.8633 | Val Loss: 1.3596 | Val Acc: 0.7891
# Epoch [620/1000] | Train Loss: 0.2804 | Train Acc: 0.8965 | Val Loss: 1.2543 | Val Acc: 0.7812
# Epoch [630/1000] | Train Loss: 0.3748 | Train Acc: 0.8662 | Val Loss: 1.5102 | Val Acc: 0.7734
# Epoch [640/1000] | Train Loss: 0.3092 | Train Acc: 0.8818 | Val Loss: 1.0297 | Val Acc: 0.7578
# Epoch [650/1000] | Train Loss: 0.4028 | Train Acc: 0.8740 | Val Loss: 1.4480 | Val Acc: 0.7461
# Epoch [660/1000] | Train Loss: 0.4658 | Train Acc: 0.8643 | Val Loss: 1.3480 | Val Acc: 0.7578
# Epoch [670/1000] | Train Loss: 0.4121 | Train Acc: 0.8789 | Val Loss: 2.6630 | Val Acc: 0.7773
# Epoch [680/1000] | Train Loss: 0.4851 | Train Acc: 0.8438 | Val Loss: 2.1567 | Val Acc: 0.7539
# Epoch [690/1000] | Train Loss: 0.5369 | Train Acc: 0.8564 | Val Loss: 1.3973 | Val Acc: 0.7188
# Epoch [700/1000] | Train Loss: 0.3739 | Train Acc: 0.8643 | Val Loss: 1.6437 | Val Acc: 0.7734
# Epoch [706] had best val_metric
# Epoch [710/1000] | Train Loss: 0.4500 | Train Acc: 0.8604 | Val Loss: 1.6292 | Val Acc: 0.7500
# Epoch [720/1000] | Train Loss: 0.4875 | Train Acc: 0.8506 | Val Loss: 1.8930 | Val Acc: 0.7852
# Epoch [730/1000] | Train Loss: 0.8518 | Train Acc: 0.7764 | Val Loss: 1.5538 | Val Acc: 0.7500
# Epoch [740/1000] | Train Loss: 0.5705 | Train Acc: 0.8594 | Val Loss: 1.8999 | Val Acc: 0.7773
# Epoch [750/1000] | Train Loss: 0.9817 | Train Acc: 0.7207 | Val Loss: 0.9992 | Val Acc: 0.7188
# Epoch [760/1000] | Train Loss: 0.3505 | Train Acc: 0.8809 | Val Loss: 1.3149 | Val Acc: 0.7812
# Epoch [770/1000] | Train Loss: 0.5352 | Train Acc: 0.8594 | Val Loss: 1.5779 | Val Acc: 0.7617
# Epoch [780/1000] | Train Loss: 0.4343 | Train Acc: 0.8594 | Val Loss: 1.4157 | Val Acc: 0.7656
# Epoch [790/1000] | Train Loss: 0.2339 | Train Acc: 0.9189 | Val Loss: 1.5442 | Val Acc: 0.8008
# Epoch [800/1000] | Train Loss: 0.8617 | Train Acc: 0.8232 | Val Loss: 2.8851 | Val Acc: 0.7617
# Epoch [810/1000] | Train Loss: 0.2649 | Train Acc: 0.9082 | Val Loss: 1.3536 | Val Acc: 0.7617
# Epoch [820/1000] | Train Loss: 0.3478 | Train Acc: 0.8945 | Val Loss: 1.7160 | Val Acc: 0.8008
# Epoch [830/1000] | Train Loss: 0.5481 | Train Acc: 0.8428 | Val Loss: 1.6581 | Val Acc: 0.7539
# Epoch [840/1000] | Train Loss: 0.4699 | Train Acc: 0.8740 | Val Loss: 2.3403 | Val Acc: 0.7773
# Epoch [846] had best val_metric
# Epoch [850/1000] | Train Loss: 0.5867 | Train Acc: 0.8799 | Val Loss: 1.6789 | Val Acc: 0.7734
# Epoch [860/1000] | Train Loss: 0.8434 | Train Acc: 0.8066 | Val Loss: 2.5131 | Val Acc: 0.7070
# Epoch [870/1000] | Train Loss: 0.7124 | Train Acc: 0.8320 | Val Loss: 2.3966 | Val Acc: 0.7617
# Epoch [880/1000] | Train Loss: 0.6946 | Train Acc: 0.8389 | Val Loss: 2.1079 | Val Acc: 0.7695
# Epoch [890/1000] | Train Loss: 0.5577 | Train Acc: 0.8721 | Val Loss: 1.9962 | Val Acc: 0.7695
# Epoch [900/1000] | Train Loss: 0.6050 | Train Acc: 0.8262 | Val Loss: 1.5740 | Val Acc: 0.7188
# Epoch [910/1000] | Train Loss: 0.4544 | Train Acc: 0.8682 | Val Loss: 2.2894 | Val Acc: 0.7930
# Epoch [920/1000] | Train Loss: 0.6197 | Train Acc: 0.8506 | Val Loss: 2.1920 | Val Acc: 0.7773
# Epoch [930/1000] | Train Loss: 0.3563 | Train Acc: 0.8975 | Val Loss: 1.1985 | Val Acc: 0.7930
# Epoch [940/1000] | Train Loss: 0.7089 | Train Acc: 0.8184 | Val Loss: 1.9654 | Val Acc: 0.7852
# Epoch [950/1000] | Train Loss: 0.6885 | Train Acc: 0.8633 | Val Loss: 3.6749 | Val Acc: 0.7500
# Epoch [960/1000] | Train Loss: 0.2612 | Train Acc: 0.9043 | Val Loss: 1.7883 | Val Acc: 0.8008
# Epoch [970/1000] | Train Loss: 0.2558 | Train Acc: 0.9033 | Val Loss: 1.7780 | Val Acc: 0.7812
# Epoch [980/1000] | Train Loss: 0.3769 | Train Acc: 0.8867 | Val Loss: 1.5573 | Val Acc: 0.7891
# Epoch [990/1000] | Train Loss: 0.3572 | Train Acc: 0.8975 | Val Loss: 2.7333 | Val Acc: 0.7578
# Epoch [1000/1000] | Train Loss: 0.4287 | Train Acc: 0.8926 | Val Loss: 1.5993 | Val Acc: 0.7852

# %%
## Save Model
# Create output directory if it doesn't exist

save = True
if save:
    os.makedirs("models", exist_ok=True)
    
    # Timestamp for unique filenames
    timestamp = datetime.now().strftime("%m%d_%H%M")
    
    # Save model states and tracked data in a single file
    save_path = f"models/Multiclass_DNN_05_{timestamp}.pt"
    torch.save({
        "DNN_state_dict": DNN.state_dict(),
        "losses": losses,
    }, save_path)
    
    print(f"Model and statistics saved to {save_path}")
# Out:
# Model and statistics saved to models/Multiclass_DNN_05_consistent_1011_0119.pt

# %%
DNN.eval()
all_targets, all_preds, all_probs = [], [], []

with torch.no_grad():
    for features, target in test_loader:
        features = features.to(device)
        target = target.to(device).long()
        outputs = DNN(features)
        
        if outputs.shape[1] == 1:
            # Binary case
            probs = torch.sigmoid(outputs).squeeze(-1)
            preds = (probs > 0.5).long()
        else:
            # Multiclass case
            probs = F.softmax(outputs, dim=1)
            preds = torch.argmax(probs, dim=1)

        all_targets.append(target.cpu())
        all_preds.append(preds.cpu())
        all_probs.append(probs.cpu())

# Concatenate
all_targets = torch.cat(all_targets).numpy()
all_preds = torch.cat(all_preds).numpy()
all_probs = torch.cat(all_probs).numpy()

# Metrics
cm = confusion_matrix(all_targets, all_preds)
acc = accuracy_score(all_targets, all_preds)
if outputs.shape[1] == 1:
    f1 = f1_score(all_targets, all_preds)
    auc_score = roc_auc_score(all_targets, all_probs)
    csi = cm[1,1] / (cm[1,1] + cm[1,0] + cm[0,1])
else:
    num_classes = outputs.shape[1]
    f1 = f1_score(all_targets, all_preds, average='macro')
    auc_score = roc_auc_score(np.eye(num_classes)[all_targets], all_probs, multi_class='ovr')
    csi = []
    for i in range(num_classes):
        tp = cm[i,i]
        fn = cm[i,:].sum() - tp
        fp = cm[:,i].sum() - tp
        csi.append(tp / (tp + fn + fp) if (tp+fn+fp)>0 else 0)

# Print metrics
print(f"AUC: {auc_score:.4f}, F1: {f1:.4f}, Accuracy: {acc:.4f}")
if outputs.shape[1] > 1:
    for i, c in enumerate(csi):
        print(f"Class {i} CSI: {c:.4f}")
else:
    print(f"CSI: {csi:.4f}")

# Confusion Matrix
plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# ROC curve
plt.figure(figsize=(7,6))
if outputs.shape[1] == 1:
    fpr, tpr, _ = roc_curve(all_targets, all_probs)
    plt.plot(fpr, tpr, label=f'AUC={auc_score:.4f}')
else:
    for i in range(num_classes):
        fpr, tpr, _ = roc_curve((all_targets==i).astype(int), all_probs[:,i])
        roc_auc = auc(fpr, tpr)
        plt.plot(fpr, tpr, label=f'Class {i} (AUC={roc_auc:.2f})')
plt.plot([0,1],[0,1], linestyle='--', color='gray')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.show()

# Overall metrics bar
metrics = {'Accuracy': acc, 'F1 Score': f1}
plt.figure(figsize=(6,4))
plt.bar(metrics.keys(), metrics.values(), color=['skyblue','orange'])
plt.ylim(0,1)
plt.title('Overall Metrics')
plt.show()

# CSI bar for multiclass
if outputs.shape[1] > 1:
    plt.figure(figsize=(6,4))
    plt.bar([f'Class {i}' for i in range(num_classes)], csi, color='green')
    plt.ylim(0,1)
    plt.title('CSI per Class')
    plt.show()
# Out:
# AUC: 0.5867, F1: 0.2530, Accuracy: 0.4531
# Class 0 CSI: 0.4503
# Class 1 CSI: 0.1667
# Class 2 CSI: 0.0556
# Class 3 CSI: 0.0000

# %%
## Load a previous model
load = True

if load:
    load_path = "models/Multiclass_DNN_05_consistent_1011_0119.pt" # Path to load model
    # load_path = "models/Multiclass_DNN_05_AUC.65.1011_0118.pt"
    # load_path = "models/Multiclass_DNN_05_1011_0115.pt"
    # load_path = "models/Multiclass_DNN_05_1011_0109.pt"
    
    # Load the checkpoint
    checkpoint = torch.load(load_path)
    
    # Restore model weights
    DNN.load_state_dict(checkpoint["DNN_state_dict"])
        
    print(f"Loaded model from {load_path}")
# Out:
# Loaded model from models/Multiclass_DNN_05_consistent_1011_0119.pt

# %%
DNN.eval()
all_targets, all_preds, all_probs = [], [], []

with torch.no_grad():
    for features, target in test_loader:
        features = features.to(device)
        target = target.to(device).long()
        outputs = DNN(features)
        
        if outputs.shape[1] == 1:
            # Binary case
            probs = torch.sigmoid(outputs).squeeze(-1)
            preds = (probs > 0.5).long()
        else:
            # Multiclass case
            probs = F.softmax(outputs, dim=1)
            preds = torch.argmax(probs, dim=1)

        all_targets.append(target.cpu())
        all_preds.append(preds.cpu())
        all_probs.append(probs.cpu())

# Concatenate
all_targets = torch.cat(all_targets).numpy()
all_preds = torch.cat(all_preds).numpy()
all_probs = torch.cat(all_probs).numpy()

# Metrics
cm = confusion_matrix(all_targets, all_preds)
acc = accuracy_score(all_targets, all_preds)
if outputs.shape[1] == 1:
    f1 = f1_score(all_targets, all_preds)
    auc_score = roc_auc_score(all_targets, all_probs)
    csi = cm[1,1] / (cm[1,1] + cm[1,0] + cm[0,1])
else:
    num_classes = outputs.shape[1]
    f1 = f1_score(all_targets, all_preds, average='macro')
    auc_score = roc_auc_score(np.eye(num_classes)[all_targets], all_probs, multi_class='ovr')
    csi = []
    for i in range(num_classes):
        tp = cm[i,i]
        fn = cm[i,:].sum() - tp
        fp = cm[:,i].sum() - tp
        csi.append(tp / (tp + fn + fp) if (tp+fn+fp)>0 else 0)

# Print metrics
print(f"AUC: {auc_score:.4f}, F1: {f1:.4f}, Accuracy: {acc:.4f}")
if outputs.shape[1] > 1:
    for i, c in enumerate(csi):
        print(f"Class {i} CSI: {c:.4f}")
else:
    print(f"CSI: {csi:.4f}")

# Confusion Matrix
plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# ROC curve
plt.figure(figsize=(7,6))
if outputs.shape[1] == 1:
    fpr, tpr, _ = roc_curve(all_targets, all_probs)
    plt.plot(fpr, tpr, label=f'AUC={auc_score:.4f}')
else:
    for i in range(num_classes):
        fpr, tpr, _ = roc_curve((all_targets==i).astype(int), all_probs[:,i])
        roc_auc = auc(fpr, tpr)
        plt.plot(fpr, tpr, label=f'Class {i} (AUC={roc_auc:.2f})')
plt.plot([0,1],[0,1], linestyle='--', color='gray')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.show()

# Overall metrics bar
metrics = {'Accuracy': acc, 'F1 Score': f1}
plt.figure(figsize=(6,4))
plt.bar(metrics.keys(), metrics.values(), color=['skyblue','orange'])
plt.ylim(0,1)
plt.title('Overall Metrics')
plt.show()

# CSI bar for multiclass
if outputs.shape[1] > 1:
    plt.figure(figsize=(6,4))
    plt.bar([f'Class {i}' for i in range(num_classes)], csi, color='green')
    plt.ylim(0,1)
    plt.title('CSI per Class')
    plt.show()
# Out:
# AUC: nan, F1: 0.2310, Accuracy: 0.5938
# Class 0 CSI: 0.5902
# Class 1 CSI: 0.1000
# Class 2 CSI: 0.0000
# Class 3 CSI: 0.0000
