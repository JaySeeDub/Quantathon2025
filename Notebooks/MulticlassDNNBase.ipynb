# %%
# All imports
from Imports import *
from Preprocessing import *
from Helper import *
# %matplotlib inline
warnings.filterwarnings('ignore')

# %%
# Load dataset and device
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# Data paths
TRAIN_FILE = '../Data/2025-Quantathon-Tornado-Q-training_data-640-examples.xlsx'
TEST_FILE = '../Data/2025-Quantum-Tornado-Q-test_data-200-examples.xlsx'
VALIDATION_FILE = '../Data/2025-Quantum-Tornado-validation_data-160-examples.xlsx'

# Load training data
df_train = pd.read_excel(TRAIN_FILE)
# Load test data
df_test = pd.read_excel(TEST_FILE)
# Load validation data
df_val = pd.read_excel(VALIDATION_FILE)
    
for i, row in df_train.head(3).iterrows():
    print(row.tolist())

print(f"✓ Training data loaded: {df_train.shape[0]} rows, {df_train.shape[1]} columns")
print(f"✓ Test data loaded: {df_test.shape[0]} rows, {df_test.shape[1]} columns")
# Out:
# [4207.767578125, 192.0945587158203, 294.7670288085937, 299.4913330078125, 33.25276184082031, 99651.6875, 10.141384342896378, 22.539603047233594, 1.0, 0.0]
# [87.97427368164062, 317.01123046875, 290.7364501953125, 304.0491943359375, 20.088348388671875, 92164.1875, 0.0089225431647932, 6.829328485761937, 0.0, 0.0]
# [0.0, nan, 287.0264892578125, 297.8692626953125, 29.98211669921875, 100696.140625, 4.3671719603330965, 9.160995228808543, 1.0, 0.0]
# ✓ Training data loaded: 640 rows, 10 columns
# ✓ Test data loaded: 200 rows, 10 columns

# %%
# Binary DN without Quantum Layer
class BinaryDNN(nn.Module):
    def __init__(self):
        super().__init__()

        # Encodes features from dataset
        self.feature_encoder = nn.Sequential(
            nn.Linear(8, 64),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.2),
            nn.Linear(64, 128),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.2)
            # nn.Linear(128, 1024),
            # nn.LeakyReLU(0.2),
            # nn.Dropout(0.2),
        )

        # Classifies based on encoded features
        self.classifier = nn.Sequential(
            # nn.Linear(1024, 128),
            # nn.LeakyReLU(0.2),
            # nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.2),
            nn.Linear(64, 4)
        )

    def forward(self, features):
        feats_encoded = self.feature_encoder(features)
        class_target = self.classifier(feats_encoded)

        return class_target  # Shape: (batch_size, 4)

# %%
# Define variable and dataset
batch_size = 64
lr = 1e-2

X_train, y_train, X_test, y_test, X_val, y_val = Preprocess(df_train, df_test, df_val, balance = 'smote', classes = 'multiclass')

print(X_train.shape, y_train.shape)
print(X_val.shape, y_val.shape)
print(X_test.shape, y_test.shape)

print(y_test[:])
print(y_train[:])
print(y_val[:])

train_data = ClassificationDataset(X_train, y_train)
validation_data = ClassificationDataset(X_val, y_val)
test_data = ClassificationDataset(X_test, y_test)

train_loader = DataLoader(train_data, batch_size=64, shuffle=True, drop_last=True)
val_loader = DataLoader(validation_data, batch_size=64, shuffle=False, drop_last=True)
test_loader = DataLoader(test_data, batch_size=64, shuffle=False, drop_last=True)

X_batch, y_batch = next(iter(train_loader))

print("Batch X dtype:", X_batch.dtype)
print("Batch y dtype:", y_batch.dtype)

print("Number of training samples:", len(train_data))
print("Number of validation samples:", len(validation_data))
print("Number of test samples:", len(test_data))
# Out:
# (1328, 8) (1328,)
# (160, 8) (160,)
# (200, 8) (200,)
# 0      1
# 1      0
# 2      1
# 3      0
# 4      2
#       ..
# 195    1
# 196    1
# 197    3
# 198    0
# 199    0
# Name: ef_class, Length: 200, dtype: int64
# 0       1
# 1       0
# 2       1
# 3       0
# 4       1
#        ..
# 1323    3
# 1324    3
# 1325    3
# 1326    3
# 1327    3
# Name: ef_class, Length: 1328, dtype: int64
# 0      0
# 1      1
# 2      2
# 3      0
# 4      0
#       ..
# 155    0
# 156    1
# 157    0
# 158    0
# 159    1
# Name: ef_class, Length: 160, dtype: int64
# Batch X dtype: torch.float32
# Batch y dtype: torch.float32
# Number of training samples: 1328
# Number of validation samples: 160
# Number of test samples: 200

# %%
# Initialize model, optimizer, and scheduler
n_epochs = 1000

DNN = BinaryDNN().to(device)
optimizer = optim.Adam(DNN.parameters(), lr=lr, betas=(0.9, 0.999))
scheduler_G = CosineAnnealingLR(optimizer, T_max=n_epochs, eta_min=1e-4)

# Empty array to track losses
losses = []

# %%
# # Plot visual of DNN
# graph =  draw_graph(
#     DNN,
#     input_size=(1, 8),
#     expand_nested=True,
#     depth = 1,
#     graph_name="DNN Architecture",
#     mode = 'train',
#     show_shapes = True,
#     hide_inner_tensors=True,   # Hides intermediate shapes
#     roll=True,                  # More compact layer grouping
#     save_graph=False,           # Set to True if you want to save
#     # node_attr={"color": "lightblue", "style": "filled"},  # Node styling
#     # edge_attr={"color": "gray"},                          # Edge styling
#     graph_dir= "TB",                         # Layout: TB (top-bottom), LR (left-right)
# )

# # Show in notebook
# graph.visual_graph

# %%
## Load a previous model
load = False

if load:
    # load_path = "models/Binary_DNN_" # Path to load model
    
    # Load the checkpoint
    checkpoint = torch.load(load_path)
    
    # Restore model weights
    DNN.load_state_dict(checkpoint["DNN_state_dict"])
    
    # Optionally restore tracking data
    losses = checkpoint["losses"]
        
    print(f"Loaded model from {load_path}")

# %%
cross_entropy = nn.CrossEntropyLoss()
metric = lambda outputs, target: (torch.argmax(outputs, dim=1) == target).float().mean().item()
best_val_metric = 0
best_val_loss = 999

history = {'epoch': [], 'train_loss': [], 'train_metric': [], 'val_loss': [], 'val_metric': []}

for epoch in range(n_epochs):
    DNN.train()
    train_loss, train_metric = 0.0, 0.0

    for features, target in train_loader:
        features, target = features.to(device), target.to(device).long()  # targets shape: (batch_size,)

        optimizer.zero_grad()
        outputs = DNN(features)              # logits: (batch_size, num_classes)
        loss = cross_entropy(outputs, target)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        train_metric += metric(outputs, target)

    train_loss /= len(train_loader)
    train_metric /= len(train_loader)

    # Validation
    DNN.eval()
    val_loss, val_metric = 0.0, 0.0
    with torch.no_grad():
        for X_val, y_val in val_loader:
            X_val, y_val = X_val.to(device), y_val.to(device).long()
            outputs = DNN(X_val)
            val_loss += cross_entropy(outputs, y_val).item()
            val_metric += metric(outputs, y_val)

    val_loss /= len(val_loader)
    val_metric /= len(val_loader)

    history['epoch'].append(epoch)
    history['train_loss'].append(train_loss)
    history['train_metric'].append(train_metric)
    history['val_loss'].append(val_loss)
    history['val_metric'].append(val_metric)

    if epoch % 10 == 9:
        print(f'Epoch [{epoch+1}/{n_epochs}] | Train Loss: {train_loss:.4f} | '
              f'Train Acc: {train_metric:.4f} | Val Loss: {val_loss:.4f} | Val Acc: {val_metric:.4f}')

    # Save best model (accuracy)
    if val_metric > best_val_metric:
        best_val_metric = val_metric
        os.makedirs("models", exist_ok=True)
        save_path = "models/DNN_multiclass_best_accuracy.pt"
        torch.save({"DNN_state_dict": DNN.state_dict(), "history": history}, save_path)
        print(f'Epoch [{epoch+1}] had best val_metric')
        

    # Save best model (val loss)
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        os.makedirs("models", exist_ok=True)
        save_path = "models/DNN_multiclass_best_valLoss.pt"
        torch.save({"DNN_state_dict": DNN.state_dict(), "history": history}, save_path)
        print(f'Epoch [{epoch+1}] had best val loss')
# Out:
# Epoch [1] had best val_metric
# Epoch [1] had best val loss
# Epoch [2] had best val_metric
# Epoch [2] had best val loss
# Epoch [7] had best val loss
# Epoch [10/1000] | Train Loss: 1.0882 | Train Acc: 0.5219 | Val Loss: 1.2916 | Val Acc: 0.3281
# Epoch [20/1000] | Train Loss: 1.0174 | Train Acc: 0.5430 | Val Loss: 1.1471 | Val Acc: 0.4609
# Epoch [20] had best val loss
# Epoch [21] had best val loss
# Epoch [30/1000] | Train Loss: 0.9451 | Train Acc: 0.5773 | Val Loss: 1.1150 | Val Acc: 0.4688
# Epoch [30] had best val loss
# Epoch [40/1000] | Train Loss: 0.9335 | Train Acc: 0.5922 | Val Loss: 1.1566 | Val Acc: 0.4297
# Epoch [50/1000] | Train Loss: 0.9157 | Train Acc: 0.5875 | Val Loss: 1.2518 | Val Acc: 0.3594
# Epoch [60/1000] | Train Loss: 0.8592 | Train Acc: 0.6391 | Val Loss: 1.2231 | Val Acc: 0.4219
# Epoch [70/1000] | Train Loss: 0.8338 | Train Acc: 0.6352 | Val Loss: 1.2353 | Val Acc: 0.4219
# Epoch [80/1000] | Train Loss: 0.8243 | Train Acc: 0.6445 | Val Loss: 1.2688 | Val Acc: 0.3984
# Epoch [90/1000] | Train Loss: 0.8075 | Train Acc: 0.6422 | Val Loss: 1.3448 | Val Acc: 0.4375
# Epoch [93] had best val_metric
# Epoch [100/1000] | Train Loss: 0.7733 | Train Acc: 0.6508 | Val Loss: 1.3261 | Val Acc: 0.4297
# Epoch [110/1000] | Train Loss: 0.8012 | Train Acc: 0.6555 | Val Loss: 1.1636 | Val Acc: 0.4531
# Epoch [115] had best val_metric
# Epoch [120/1000] | Train Loss: 0.7931 | Train Acc: 0.6469 | Val Loss: 1.2011 | Val Acc: 0.4766
# Epoch [130/1000] | Train Loss: 0.7589 | Train Acc: 0.6781 | Val Loss: 1.2492 | Val Acc: 0.4453
# Epoch [140/1000] | Train Loss: 0.7364 | Train Acc: 0.6906 | Val Loss: 1.2663 | Val Acc: 0.4219
# Epoch [150/1000] | Train Loss: 0.7215 | Train Acc: 0.6852 | Val Loss: 1.3627 | Val Acc: 0.3984
# Epoch [160/1000] | Train Loss: 0.7554 | Train Acc: 0.6781 | Val Loss: 1.3695 | Val Acc: 0.3672
# Epoch [170/1000] | Train Loss: 0.7148 | Train Acc: 0.6953 | Val Loss: 1.3172 | Val Acc: 0.4453
# Epoch [180/1000] | Train Loss: 0.7013 | Train Acc: 0.6922 | Val Loss: 1.4686 | Val Acc: 0.3750
# Epoch [190/1000] | Train Loss: 0.7081 | Train Acc: 0.7047 | Val Loss: 1.2583 | Val Acc: 0.4531
# Epoch [200/1000] | Train Loss: 0.7456 | Train Acc: 0.6906 | Val Loss: 1.4427 | Val Acc: 0.4297
# Epoch [210/1000] | Train Loss: 0.7407 | Train Acc: 0.6805 | Val Loss: 1.3795 | Val Acc: 0.4141
# Epoch [220/1000] | Train Loss: 0.7115 | Train Acc: 0.7086 | Val Loss: 1.3144 | Val Acc: 0.4766
# Epoch [223] had best val_metric
# Epoch [230/1000] | Train Loss: 0.7122 | Train Acc: 0.7000 | Val Loss: 1.2635 | Val Acc: 0.4531
# Epoch [240/1000] | Train Loss: 0.6862 | Train Acc: 0.7109 | Val Loss: 1.2900 | Val Acc: 0.4375
# Epoch [250/1000] | Train Loss: 0.6553 | Train Acc: 0.7148 | Val Loss: 1.3029 | Val Acc: 0.4609
# Epoch [260/1000] | Train Loss: 0.6539 | Train Acc: 0.7164 | Val Loss: 1.2346 | Val Acc: 0.4844
# Epoch [270/1000] | Train Loss: 0.6621 | Train Acc: 0.7117 | Val Loss: 1.3363 | Val Acc: 0.4688
# Epoch [280/1000] | Train Loss: 0.6642 | Train Acc: 0.7188 | Val Loss: 1.4845 | Val Acc: 0.3516
# Epoch [290/1000] | Train Loss: 0.6436 | Train Acc: 0.7312 | Val Loss: 1.3160 | Val Acc: 0.4531
# Epoch [300/1000] | Train Loss: 0.6182 | Train Acc: 0.7484 | Val Loss: 1.2453 | Val Acc: 0.5078
# Epoch [310/1000] | Train Loss: 0.6325 | Train Acc: 0.7352 | Val Loss: 1.3771 | Val Acc: 0.4766
# Epoch [320/1000] | Train Loss: 0.6563 | Train Acc: 0.7344 | Val Loss: 1.3096 | Val Acc: 0.4453
# Epoch [330/1000] | Train Loss: 0.6524 | Train Acc: 0.7250 | Val Loss: 1.5364 | Val Acc: 0.4141
# Epoch [340/1000] | Train Loss: 0.6479 | Train Acc: 0.7273 | Val Loss: 1.3712 | Val Acc: 0.4844
# Epoch [350/1000] | Train Loss: 0.6975 | Train Acc: 0.7164 | Val Loss: 1.3289 | Val Acc: 0.4688
# Epoch [360/1000] | Train Loss: 0.5983 | Train Acc: 0.7453 | Val Loss: 1.4770 | Val Acc: 0.3906
# Epoch [370/1000] | Train Loss: 0.6151 | Train Acc: 0.7414 | Val Loss: 1.2863 | Val Acc: 0.5312
# Epoch [380/1000] | Train Loss: 0.6400 | Train Acc: 0.7359 | Val Loss: 1.2570 | Val Acc: 0.5156
# Epoch [390/1000] | Train Loss: 0.5995 | Train Acc: 0.7445 | Val Loss: 1.4167 | Val Acc: 0.4219
# Epoch [400/1000] | Train Loss: 0.6204 | Train Acc: 0.7430 | Val Loss: 1.2265 | Val Acc: 0.5234
# Epoch [410/1000] | Train Loss: 0.5977 | Train Acc: 0.7453 | Val Loss: 1.3313 | Val Acc: 0.4688
# Epoch [420/1000] | Train Loss: 0.6512 | Train Acc: 0.7305 | Val Loss: 1.3937 | Val Acc: 0.4297
# Epoch [430/1000] | Train Loss: 0.6290 | Train Acc: 0.7453 | Val Loss: 1.2626 | Val Acc: 0.5781
# Epoch [440/1000] | Train Loss: 0.6227 | Train Acc: 0.7406 | Val Loss: 1.3651 | Val Acc: 0.5000
# Epoch [450/1000] | Train Loss: 0.6061 | Train Acc: 0.7469 | Val Loss: 1.3711 | Val Acc: 0.4844
# Epoch [460/1000] | Train Loss: 0.6136 | Train Acc: 0.7492 | Val Loss: 1.2870 | Val Acc: 0.5078
# Epoch [470/1000] | Train Loss: 0.5833 | Train Acc: 0.7555 | Val Loss: 1.4588 | Val Acc: 0.4688
# Epoch [480/1000] | Train Loss: 0.5876 | Train Acc: 0.7633 | Val Loss: 1.3923 | Val Acc: 0.5625
# Epoch [490/1000] | Train Loss: 0.5916 | Train Acc: 0.7625 | Val Loss: 1.4062 | Val Acc: 0.4922
# Epoch [500/1000] | Train Loss: 0.6525 | Train Acc: 0.7391 | Val Loss: 1.3039 | Val Acc: 0.5000
# Epoch [510/1000] | Train Loss: 0.6287 | Train Acc: 0.7562 | Val Loss: 1.3648 | Val Acc: 0.5000
# Epoch [520/1000] | Train Loss: 0.6327 | Train Acc: 0.7383 | Val Loss: 1.3002 | Val Acc: 0.5391
# Epoch [530/1000] | Train Loss: 0.6172 | Train Acc: 0.7391 | Val Loss: 1.3066 | Val Acc: 0.5156
# Epoch [540/1000] | Train Loss: 0.5735 | Train Acc: 0.7516 | Val Loss: 1.3442 | Val Acc: 0.4766
# Epoch [550/1000] | Train Loss: 0.6098 | Train Acc: 0.7367 | Val Loss: 1.3593 | Val Acc: 0.5312
# Epoch [560/1000] | Train Loss: 0.6309 | Train Acc: 0.7398 | Val Loss: 1.4015 | Val Acc: 0.4609
# Epoch [570/1000] | Train Loss: 0.6291 | Train Acc: 0.7531 | Val Loss: 1.4219 | Val Acc: 0.4844
# Epoch [580/1000] | Train Loss: 0.6391 | Train Acc: 0.7273 | Val Loss: 1.3393 | Val Acc: 0.4922
# Epoch [590/1000] | Train Loss: 0.5847 | Train Acc: 0.7562 | Val Loss: 1.3603 | Val Acc: 0.5234
# Epoch [600/1000] | Train Loss: 0.5946 | Train Acc: 0.7430 | Val Loss: 1.4066 | Val Acc: 0.5000
# Epoch [610/1000] | Train Loss: 0.6331 | Train Acc: 0.7367 | Val Loss: 1.2701 | Val Acc: 0.5469
# Epoch [620/1000] | Train Loss: 0.5972 | Train Acc: 0.7602 | Val Loss: 1.3575 | Val Acc: 0.5078
# Epoch [630/1000] | Train Loss: 0.5808 | Train Acc: 0.7523 | Val Loss: 1.4382 | Val Acc: 0.4844
# Epoch [640/1000] | Train Loss: 0.5812 | Train Acc: 0.7641 | Val Loss: 1.4771 | Val Acc: 0.4766
# Epoch [650/1000] | Train Loss: 0.6041 | Train Acc: 0.7586 | Val Loss: 1.5027 | Val Acc: 0.4844
# Epoch [660/1000] | Train Loss: 0.5860 | Train Acc: 0.7531 | Val Loss: 1.4030 | Val Acc: 0.4688
# Epoch [670/1000] | Train Loss: 0.5583 | Train Acc: 0.7703 | Val Loss: 1.4137 | Val Acc: 0.5312
# Epoch [680/1000] | Train Loss: 0.5772 | Train Acc: 0.7633 | Val Loss: 1.4669 | Val Acc: 0.5000
# Epoch [689] had best val_metric
# Epoch [690/1000] | Train Loss: 0.5918 | Train Acc: 0.7570 | Val Loss: 1.3354 | Val Acc: 0.5234
# Epoch [700/1000] | Train Loss: 0.5682 | Train Acc: 0.7602 | Val Loss: 1.3394 | Val Acc: 0.4844
# Epoch [710/1000] | Train Loss: 0.6018 | Train Acc: 0.7492 | Val Loss: 1.3943 | Val Acc: 0.5078
# Epoch [720/1000] | Train Loss: 0.6089 | Train Acc: 0.7422 | Val Loss: 1.2817 | Val Acc: 0.5234
# Epoch [730/1000] | Train Loss: 0.5594 | Train Acc: 0.7789 | Val Loss: 1.4215 | Val Acc: 0.4922
# Epoch [740/1000] | Train Loss: 0.5904 | Train Acc: 0.7586 | Val Loss: 1.5719 | Val Acc: 0.4844
# Epoch [750/1000] | Train Loss: 0.5834 | Train Acc: 0.7586 | Val Loss: 1.4691 | Val Acc: 0.4688
# Epoch [760/1000] | Train Loss: 0.5938 | Train Acc: 0.7461 | Val Loss: 1.4067 | Val Acc: 0.4688
# Epoch [770/1000] | Train Loss: 0.6085 | Train Acc: 0.7508 | Val Loss: 1.3406 | Val Acc: 0.4531
# Epoch [780/1000] | Train Loss: 0.5733 | Train Acc: 0.7648 | Val Loss: 1.3810 | Val Acc: 0.5391
# Epoch [790/1000] | Train Loss: 0.5652 | Train Acc: 0.7688 | Val Loss: 1.3523 | Val Acc: 0.4922
# Epoch [800/1000] | Train Loss: 0.5700 | Train Acc: 0.7648 | Val Loss: 1.2931 | Val Acc: 0.4609
# Epoch [810/1000] | Train Loss: 0.5922 | Train Acc: 0.7664 | Val Loss: 1.3692 | Val Acc: 0.5000
# Epoch [820/1000] | Train Loss: 0.5650 | Train Acc: 0.7602 | Val Loss: 1.4397 | Val Acc: 0.4766
# Epoch [830/1000] | Train Loss: 0.5843 | Train Acc: 0.7727 | Val Loss: 1.4266 | Val Acc: 0.5156
# Epoch [840/1000] | Train Loss: 0.5579 | Train Acc: 0.7664 | Val Loss: 1.4155 | Val Acc: 0.5156
# Epoch [850/1000] | Train Loss: 0.6465 | Train Acc: 0.7281 | Val Loss: 1.3611 | Val Acc: 0.5312
# Epoch [860/1000] | Train Loss: 0.5987 | Train Acc: 0.7469 | Val Loss: 1.3402 | Val Acc: 0.5234
# Epoch [870/1000] | Train Loss: 0.5802 | Train Acc: 0.7625 | Val Loss: 1.4667 | Val Acc: 0.5000
# Epoch [880/1000] | Train Loss: 0.5640 | Train Acc: 0.7727 | Val Loss: 1.3617 | Val Acc: 0.5391
# Epoch [890/1000] | Train Loss: 0.6208 | Train Acc: 0.7539 | Val Loss: 1.5164 | Val Acc: 0.5625
# Epoch [900/1000] | Train Loss: 0.5476 | Train Acc: 0.7766 | Val Loss: 1.5229 | Val Acc: 0.5312
# Epoch [910/1000] | Train Loss: 0.5891 | Train Acc: 0.7758 | Val Loss: 1.3225 | Val Acc: 0.5234
# Epoch [920/1000] | Train Loss: 0.6006 | Train Acc: 0.7570 | Val Loss: 1.4011 | Val Acc: 0.5469
# Epoch [930/1000] | Train Loss: 0.5604 | Train Acc: 0.7664 | Val Loss: 1.3020 | Val Acc: 0.5234
# Epoch [940/1000] | Train Loss: 0.5850 | Train Acc: 0.7625 | Val Loss: 1.5479 | Val Acc: 0.4688
# Epoch [950/1000] | Train Loss: 0.5418 | Train Acc: 0.7844 | Val Loss: 1.5854 | Val Acc: 0.4062
# Epoch [960/1000] | Train Loss: 0.5746 | Train Acc: 0.7805 | Val Loss: 1.5004 | Val Acc: 0.4688
# Epoch [970/1000] | Train Loss: 0.6006 | Train Acc: 0.7516 | Val Loss: 1.4483 | Val Acc: 0.4922
# Epoch [980/1000] | Train Loss: 0.5767 | Train Acc: 0.7586 | Val Loss: 1.3805 | Val Acc: 0.4766
# Epoch [990/1000] | Train Loss: 0.5735 | Train Acc: 0.7648 | Val Loss: 1.4608 | Val Acc: 0.4688
# Epoch [1000/1000] | Train Loss: 0.5521 | Train Acc: 0.7727 | Val Loss: 1.4183 | Val Acc: 0.4844

# %%
## Save Model
# Create output directory if it doesn't exist
save = True
if save:
    os.makedirs("models", exist_ok=True)
    
    # Timestamp for unique filenames
    timestamp = datetime.now().strftime("%m%d_%H%M")
    
    # Save model states and tracked data in a single file
    save_path = f"models/Multiclass_DNN_Base_bestvalLoss.{timestamp}.pt"
    torch.save({
        "DNN_state_dict": DNN.state_dict(),
        "losses": losses,
    }, save_path)
    
    print(f"Model and statistics saved to {save_path}")
# Out:
# Model and statistics saved to models/Multiclass_DNN_Base_bestvalLoss.1020_1138.pt

# %%
DNN.eval()
all_targets, all_preds, all_probs = [], [], []

with torch.no_grad():
    for features, target in test_loader:
        features = features.to(device)
        target = target.to(device).long()
        outputs = DNN(features)
        
        if outputs.shape[1] == 1:
            # Binary case
            probs = torch.sigmoid(outputs).squeeze(-1)
            preds = (probs > 0.5).long()
        else:
            # Multiclass case
            probs = F.softmax(outputs, dim=1)
            preds = torch.argmax(probs, dim=1)

        all_targets.append(target.cpu())
        all_preds.append(preds.cpu())
        all_probs.append(probs.cpu())

# Concatenate
all_targets = torch.cat(all_targets).numpy()
all_preds = torch.cat(all_preds).numpy()
all_probs = torch.cat(all_probs).numpy()

# Metrics
cm = confusion_matrix(all_targets, all_preds)
acc = accuracy_score(all_targets, all_preds)
if outputs.shape[1] == 1:
    f1 = f1_score(all_targets, all_preds)
    auc_score = roc_auc_score(all_targets, all_probs)
    csi = cm[1,1] / (cm[1,1] + cm[1,0] + cm[0,1])
else:
    num_classes = outputs.shape[1]
    f1 = f1_score(all_targets, all_preds, average='macro')
    auc_score = roc_auc_score(np.eye(num_classes)[all_targets], all_probs, multi_class='ovr')
    csi = []
    for i in range(num_classes):
        tp = cm[i,i]
        fn = cm[i,:].sum() - tp
        fp = cm[:,i].sum() - tp
        csi.append(tp / (tp + fn + fp) if (tp+fn+fp)>0 else 0)

# Print metrics
print(f"AUC: {auc_score:.4f}, F1: {f1:.4f}, Accuracy: {acc:.4f}")
if outputs.shape[1] > 1:
    for i, c in enumerate(csi):
        print(f"Class {i} CSI: {c:.4f}")
else:
    print(f"CSI: {csi:.4f}")

# Confusion Matrix
plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# ROC curve
plt.figure(figsize=(7,6))
if outputs.shape[1] == 1:
    fpr, tpr, _ = roc_curve(all_targets, all_probs)
    plt.plot(fpr, tpr, label=f'AUC={auc_score:.4f}')
else:
    for i in range(num_classes):
        fpr, tpr, _ = roc_curve((all_targets==i).astype(int), all_probs[:,i])
        roc_auc = auc(fpr, tpr)
        plt.plot(fpr, tpr, label=f'Class {i} (AUC={roc_auc:.2f})')
plt.plot([0,1],[0,1], linestyle='--', color='gray')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.show()

# Overall metrics bar
metrics = {'Accuracy': acc, 'F1 Score': f1}
plt.figure(figsize=(6,4))
plt.bar(metrics.keys(), metrics.values(), color=['skyblue','orange'])
plt.ylim(0,1)
plt.title('Overall Metrics')
plt.show()

# CSI bar for multiclass
if outputs.shape[1] > 1:
    plt.figure(figsize=(6,4))
    plt.bar([f'Class {i}' for i in range(num_classes)], csi, color='green')
    plt.ylim(0,1)
    plt.title('CSI per Class')
    plt.show()
# Out:
# AUC: 0.6268, F1: 0.3331, Accuracy: 0.5104
# Class 0 CSI: 0.4553
# Class 1 CSI: 0.3393
# Class 2 CSI: 0.1111
# Class 3 CSI: 0.0000

# %%
## Load a previous model
load = True

if load:
    # load_path = "models/DNN_multiclass_best_valLoss.pt" # Path to load model
    load_path = "models/Multiclass_DNN_Base_bestvalLoss.1011_0723.pt"
    # load_path = "models/DNN_multiclass_best_valLoss.pt"
    
    # Load the checkpoint
    checkpoint = torch.load(load_path)
    
    # Restore model weights
    DNN.load_state_dict(checkpoint["DNN_state_dict"])
        
    print(f"Loaded model from {load_path}")
# Out:
# Loaded model from models/Multiclass_DNN_Base_bestvalLoss.1011_0723.pt

# %%
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
plt.rcParams.update({
    "figure.dpi": 150,
    "font.size": 16,
    "axes.titlesize": 20,
    "axes.labelsize": 18
})
